# %%
import pandas as pd

# %%
df=pd.read_csv('kaggle_credit_score.csv')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26124\4153552702.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('kaggle_credit_score.csv')

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age          SSN  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh    23  821-00-0265
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh    23  821-00-0265
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  -500  821-00-0265
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh    23  821-00-0265
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh    23  821-00-0265
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh    23  821-00-0265
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh    23  821-00-0265
# 7  0x1609   CUS_0xd40    August              NaN    23    #F%$D@*&8
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj   28_  004-07-5839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj    28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# ...

# %%
df1=df.copy()

# %%
df1.drop(['ID','Customer_ID','Name','SSN'],axis=1,inplace=True)

# %%
df1.head(10)
# Out:
#       Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0   January    23  Scientist      19114.12            1824.843333
# 1  February    23  Scientist      19114.12                    NaN
# 2     March  -500  Scientist      19114.12                    NaN
# 3     April    23  Scientist      19114.12                    NaN
# 4       May    23  Scientist      19114.12            1824.843333
# 5      June    23  Scientist      19114.12                    NaN
# 6      July    23  Scientist      19114.12            1824.843333
# 7    August    23  Scientist      19114.12            1824.843333
# 8   January   28_    _______      34847.84            3037.986667
# 9  February    28    Teacher      34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 1                  3                4              3           4
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  object
#  1   Age                       100000 non-null  object
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  object
#  4   Monthly_Inhand_Salary     84998 non-null   float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  object
#  9   Type_of_Loan              88592 non-null   object
#  10  Delay_from_due_date       100000 non-null  int64
#  11  Num_of_Delayed_Payment    92998 non-null   object
#  12  Changed_Credit_Limit      100000 non-null  object
# ...

# %%
df1['Occupation'].unique()
# Out:
# array(['Scientist', '_______', 'Teacher', 'Engineer', 'Entrepreneur',
#        'Developer', 'Lawyer', 'Media_Manager', 'Doctor', 'Journalist',
#        'Manager', 'Accountant', 'Musician', 'Mechanic', 'Writer',
#        'Architect'], dtype=object)

# %%
df1.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
df1.shape
# Out:
# (100000, 24)

# %%
def age(val):
    try:
        val_split=val.split('_')[0]
        return int(val_split)
    except:
        return int(val)

# %%
df1['Age']=df['Age'].apply(age)

# %%
df1.head(65)
# Out:
#        Month  Age     Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0    January   23      Scientist      19114.12            1824.843333
# 1   February   23      Scientist      19114.12                    NaN
# 2      March -500      Scientist      19114.12                    NaN
# 3      April   23      Scientist      19114.12                    NaN
# 4        May   23      Scientist      19114.12            1824.843333
# ..       ...  ...            ...           ...                    ...
# 60       May   30        _______      34081.38            2611.115000
# 61      June   30  Media_Manager      34081.38            2611.115000
# 62      July   30  Media_Manager      34081.38                    NaN
# 63    August   30  Media_Manager      34081.38            2611.115000
# 64   January   23         Doctor     114838.41            9843.867500
#
#     Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# ...

# %%
df1.describe()
# Out:
#                  Age  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000           84998.000000      100000.000000
# mean      110.649700            4194.170850          17.091280
# std       686.244717            3183.686167         117.404834
# min      -500.000000             303.645417          -1.000000
# 25%        24.000000            1625.568229           3.000000
# 50%        33.000000            3093.745000           6.000000
# 75%        42.000000            5957.448333           7.000000
# max      8698.000000           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# count     100000.00000  100000.000000        100000.000000
# mean          22.47443      72.466040            21.068780
# std          129.05741     466.422621            14.860104
# min            0.00000       1.000000            -5.000000
# 25%            4.00000       8.000000            10.000000
# ...

# %%
df1['Monthly_Inhand_Salary']=df1['Monthly_Inhand_Salary'].fillna(df1['Monthly_Inhand_Salary'].mean())

# %%
df1.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
def ann_inc(val):
    try:
        spl_val=val.split('_')[0]
        return float(spl_val)
    except:
        
        return float(val)

# %%
df1['Annual_Income']=df1['Annual_Income'].apply(ann_inc)

# %%
def num_loan(val):
     try:
        spl_val=val.split('_')[0]
        return int(spl_val)
     except:
        
        return int(val)

# %%
df1['Num_of_Loan']=df1['Num_of_Loan'].apply(num_loan)

# %%
def num_delayed(val):
    try:
        if val=='NaN':
            return 0
        else:
            spl_val=val.split('_')[0]
            return float(spl_val)
    except:
            return float(val)

# %%
df1['Num_of_Delayed_Payment']=df1['Num_of_Delayed_Payment'].apply(num_delayed)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  object
#  1   Age                       100000 non-null  int64
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  int64
#  9   Type_of_Loan              88592 non-null   object
#  10  Delay_from_due_date       100000 non-null  int64
#  11  Num_of_Delayed_Payment    92998 non-null   float64
#  12  Changed_Credit_Limit      100000 non-null  object
# ...

# %%
df1['Num_of_Delayed_Payment'].head(50)
# Out:
# 0      7.0
# 1      NaN
# 2      7.0
# 3      4.0
# 4      NaN
# 5      4.0
# 6      8.0
# 7      6.0
# 8      4.0
# 9      1.0
# 10    -1.0
# 11     3.0
# 12     1.0
# 13     0.0
# 14     4.0
# 15     4.0
# 16     8.0
# 17     6.0
# 18     7.0
# 19     5.0
# 20     5.0
# 21     6.0
# 22     6.0
# 23     6.0
# 24     6.0
# 25     3.0
# 26     9.0
# 27     6.0
# 28     6.0
# 29     6.0
# 30     NaN
# 31     9.0
# 32     NaN
# 33     NaN
# 34    12.0
# 35    15.0
# 36    17.0
# 37    15.0
# 38    15.0
# 39    15.0
# 40    10.0
# 41     7.0
# 42     7.0
# 43     7.0
# 44     7.0
# 45     7.0
# 46     4.0
# 47     7.0
# 48     3.0
# 49     2.0
# Name: Num_of_Delayed_Payment, dtype: float64

# %%
df1['Num_of_Delayed_Payment']=df1['Num_of_Delayed_Payment'].fillna(df1['Num_of_Delayed_Payment'].mean())

# %%
df1['Num_of_Delayed_Payment']=df1['Num_of_Delayed_Payment'].apply(lambda val: int(val))

# %%
df1['Num_Credit_Inquiries']=df1['Num_Credit_Inquiries'].fillna(df1['Num_Credit_Inquiries'].mean())

# %%
def crdt_years(val):
    try:
        split_val=val.split(' ')[0]
        return int(split_val)
    except:
        return val

# %%
df1['Credit_History_Age']=df1['Credit_History_Age'].apply(crdt_years)

# %%
df1['Credit_History_Age']
# Out:
# 0        22.0
# 1         NaN
# 2        22.0
# 3        22.0
# 4        22.0
#          ...
# 99995    31.0
# 99996    31.0
# 99997    31.0
# 99998    31.0
# 99999    31.0
# Name: Credit_History_Age, Length: 100000, dtype: float64

# %%
df1['Credit_History_Age']=df1['Credit_History_Age'].fillna(df1['Credit_History_Age'].mean())

# %%
def amnt_invt(val):
    try:
        spl_val=val.split('_')[2]
        return float(spl_val)
    except:
        return float(val)

# %%
df1['Amount_invested_monthly']=df1['Amount_invested_monthly'].apply(amnt_invt)

# %%
df1['Amount_invested_monthly'].head(65)
# Out:
# 0      80.415295
# 1     118.280222
# 2      81.699521
# 3     199.458074
# 4      41.420153
#          ...
# 60           NaN
# 61           NaN
# 62     55.459781
# 63     29.326364
# 64    215.193516
# Name: Amount_invested_monthly, Length: 65, dtype: float64

# %%
df1['Amount_invested_monthly']=df1['Amount_invested_monthly'].fillna(df1['Amount_invested_monthly'].mean())

# %%
def mnt_bal(val):
    try:
        spl_val=val.split('_')[2]
        return float(spl_val)
    except:
        return float(val)

# %%
df1['Monthly_Balance']=df1['Monthly_Balance'].apply(mnt_bal)

# %%
df1.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment          0
# Changed_Credit_Limit            0
# Num_Credit_Inquiries            0
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  object
#  1   Age                       100000 non-null  int64
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  int64
#  9   Type_of_Loan              88592 non-null   object
#  10  Delay_from_due_date       100000 non-null  int64
#  11  Num_of_Delayed_Payment    100000 non-null  int64
#  12  Changed_Credit_Limit      100000 non-null  object
# ...

# %%
df1['Monthly_Balance']=df1['Monthly_Balance'].fillna(df1['Monthly_Balance'].mean())

# %%
df2=df1.copy()

# %%
def chge_crdt_lmt(val):
    try:
        if val=='_':
            return 
        else:
            return float(val)
    except:
        return float(val)

# %%
df2['Changed_Credit_Limit']=df2['Changed_Credit_Limit'].apply(chge_crdt_lmt)

# %%
df2.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment          0
# Changed_Credit_Limit         2091
# Num_Credit_Inquiries            0
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance                 0
# Credit_Score                    0
# dtype: int64

# %%
df2['Changed_Credit_Limit']=df2['Changed_Credit_Limit'].fillna(df2['Changed_Credit_Limit'].mean())

# %%
def out_debt(val):
    try:
        splt_val=val.split('_')[0]
        return float(splt_val)
    except:
        return float(val)

# %%
df2['Outstanding_Debt']=df2['Outstanding_Debt'].apply(out_debt)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  object
#  1   Age                       100000 non-null  int64
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  int64
#  9   Type_of_Loan              88592 non-null   object
#  10  Delay_from_due_date       100000 non-null  int64
#  11  Num_of_Delayed_Payment    100000 non-null  int64
#  12  Changed_Credit_Limit      100000 non-null  float64
# ...

# %%
def crdt_mix(val):
    try:
        if val=="_":
            return 
        else:
            return val
    except:
        return val

# %%
df2['Credit_Mix']=df2['Credit_Mix'].apply(crdt_mix)

# %%
df2.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment          0
# Changed_Credit_Limit            0
# Num_Credit_Inquiries            0
# Credit_Mix                  20195
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance                 0
# Credit_Score                    0
# dtype: int64

# %%
df2['Credit_Mix'].unique()
# Out:
# array([None, 'Good', 'Standard', 'Bad'], dtype=object)

# %%
df2.shape
# Out:
# (100000, 24)

# %%
df1.shape
# Out:
# (100000, 24)

# %%
df2['Credit_Mix'].value_counts()
# Out:
# Credit_Mix
# Standard    36479
# Good        24337
# Bad         18989
# Name: count, dtype: int64

# %%
df2['Type_of_Loan'].value_counts()
# Out:
# Type_of_Loan
# Not Specified                                                                                                                         1408
# Credit-Builder Loan                                                                                                                   1280
# Personal Loan                                                                                                                         1272
# Debt Consolidation Loan                                                                                                               1264
# Student Loan                                                                                                                          1240
#                                                                                                                                       ...
# ...

# %%
df2['Occupation'].value_counts()
# Out:
# Occupation
# _______          7062
# Lawyer           6575
# Architect        6355
# Engineer         6350
# Scientist        6299
# Mechanic         6291
# Accountant       6271
# Developer        6235
# Media_Manager    6232
# Teacher          6215
# Entrepreneur     6174
# Doctor           6087
# Journalist       6085
# Manager          5973
# Musician         5911
# Writer           5885
# Name: count, dtype: int64

# %%
df2=df2.replace('_______','Lawyer')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  object
#  1   Age                       100000 non-null  int64
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  int64
#  9   Type_of_Loan              88592 non-null   object
#  10  Delay_from_due_date       100000 non-null  int64
#  11  Num_of_Delayed_Payment    100000 non-null  int64
#  12  Changed_Credit_Limit      100000 non-null  float64
# ...

# %%
df2['Payment_of_Min_Amount'].value_counts()
# Out:
# Payment_of_Min_Amount
# Yes    52326
# No     35667
# NM     12007
# Name: count, dtype: int64

# %%
df2=df2.replace('NM','No')

# %%
df3=df2.copy()

# %%
df2.isna().sum()
# Out:
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary           0
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment          0
# Changed_Credit_Limit            0
# Num_Credit_Inquiries            0
# Credit_Mix                  20195
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age              0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly         0
# Payment_Behaviour               0
# Monthly_Balance                 0
# Credit_Score                    0
# dtype: int64

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (70805, 24)

# %%
import matplotlib.pyplot as plt

# %%
new = df2.groupby('Credit_Score').count()['Month'].reset_index()
new
# Out:
#   Credit_Score  Month
# 0         Good  11476
# 1         Poor  22071
# 2     Standard  37258

# %%
x=new['Credit_Score']
y=new['Month']
plt.bar(x,y)
plt.show()

# %%
df2.head(10)
# Out:
#        Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 1   February   23  Scientist       19114.12            4194.170850
# 2      March -500  Scientist       19114.12            4194.170850
# 3      April   23  Scientist       19114.12            4194.170850
# 4        May   23  Scientist       19114.12            1824.843333
# 5       June   23  Scientist       19114.12            4194.170850
# 6       July   23  Scientist       19114.12            1824.843333
# 7     August   23  Scientist       19114.12            1824.843333
# 8    January   28     Lawyer       34847.84            3037.986667
# 9   February   28    Teacher       34847.84            3037.986667
# 11     April   28    Teacher       34847.84            4194.170850
#
#     Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 1                   3                4              3            4
# 2                   3                4              3            4
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70805 entries, 1 to 99999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     70805 non-null  object
#  1   Age                       70805 non-null  int64
#  2   Occupation                70805 non-null  object
#  3   Annual_Income             70805 non-null  float64
#  4   Monthly_Inhand_Salary     70805 non-null  float64
#  5   Num_Bank_Accounts         70805 non-null  int64
#  6   Num_Credit_Card           70805 non-null  int64
#  7   Interest_Rate             70805 non-null  int64
#  8   Num_of_Loan               70805 non-null  int64
#  9   Type_of_Loan              70805 non-null  object
#  10  Delay_from_due_date       70805 non-null  int64
#  11  Num_of_Delayed_Payment    70805 non-null  int64
#  12  Changed_Credit_Limit      70805 non-null  float64
# ...

# %%
df2.head()
# Out:
#       Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 1  February   23  Scientist       19114.12            4194.170850
# 2     March -500  Scientist       19114.12            4194.170850
# 3     April   23  Scientist       19114.12            4194.170850
# 4       May   23  Scientist       19114.12            1824.843333
# 5      June   23  Scientist       19114.12            4194.170850
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 1                  3                4              3            4
# 2                  3                4              3            4
# 3                  3                4              3            4
# 4                  3                4              3            4
# 5                  3                4              3            4
#
#                                         Type_of_Loan  ...  Credit_Mix  \
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...        Good
# ...

# %%
def age(val):
    try:
        if val>100 or val<10:
            return 
        else:
            return int(val)
    except:
        return val

# %%
df2['Age']=df2['Age'].apply(age)

# %%
df2.isna().sum()
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df2['Age']=df2['Age'].fillna(df2['Age'].mean())

# %%
df2.head()
# Out:
#       Month        Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 1  February  23.000000  Scientist       19114.12            4194.170850
# 2     March  32.931101  Scientist       19114.12            4194.170850
# 3     April  23.000000  Scientist       19114.12            4194.170850
# 4       May  23.000000  Scientist       19114.12            1824.843333
# 5      June  23.000000  Scientist       19114.12            4194.170850
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 1                  3                4              3            4
# 2                  3                4              3            4
# 3                  3                4              3            4
# 4                  3                4              3            4
# 5                  3                4              3            4
#
#                                         Type_of_Loan  ...  Credit_Mix  \
# ...

# %%
df4=df2.drop('Type_of_Loan',axis=1)

# %%
df4
# Out:
#           Month        Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 1      February  23.000000  Scientist       19114.12            4194.170850
# 2         March  32.931101  Scientist       19114.12            4194.170850
# 3         April  23.000000  Scientist       19114.12            4194.170850
# 4           May  23.000000  Scientist       19114.12            1824.843333
# 5          June  23.000000  Scientist       19114.12            4194.170850
# ...         ...        ...        ...            ...                    ...
# 99991    August  29.000000  Architect       20002.88            1929.906667
# 99993  February  25.000000   Mechanic       39628.99            3359.415833
# 99997      June  25.000000   Mechanic       39628.99            3359.415833
# 99998      July  25.000000   Mechanic       39628.99            3359.415833
# 99999    August  25.000000   Mechanic       39628.99            3359.415833
#
# ...

# %%
df4.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  70805.000000   7.080500e+04           70805.000000       70805.000000
# mean      32.931101   1.744377e+05            4092.017300           5.754802
# std       10.516564   1.425573e+06            2877.969107           2.313999
# min       14.000000   7.005930e+03             303.645417           1.000000
# 25%       24.000000   1.899085e+04            1727.835000           4.000000
# 50%       32.931101   3.671763e+04            3730.970000           6.000000
# 75%       41.000000   7.070904e+04            5205.535000           8.000000
# max      100.000000   2.419806e+07           15204.633333          18.000000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     70805.000000   70805.000000  70805.000000         70805.000000
# mean         22.275630      74.979648      3.394563            22.002740
# ...

# %%
def account(val):
    try:
        if val>20 or val<1:
            return 
        else:
            return int(val)
    except:
        return val

# %%
df4['Num_Bank_Accounts']=df4['Num_Bank_Accounts'].apply(account)

# %%
df4['Num_Bank_Accounts']=df4['Num_Bank_Accounts'].fillna(df4['Num_Bank_Accounts'].mean())

# %%
df4.isna().sum()
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70805 entries, 1 to 99999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     70805 non-null  object
#  1   Age                       70805 non-null  float64
#  2   Occupation                70805 non-null  object
#  3   Annual_Income             70805 non-null  float64
#  4   Monthly_Inhand_Salary     70805 non-null  float64
#  5   Num_Bank_Accounts         70805 non-null  float64
#  6   Num_Credit_Card           70805 non-null  int64
#  7   Interest_Rate             70805 non-null  int64
#  8   Num_of_Loan               70805 non-null  int64
#  9   Delay_from_due_date       70805 non-null  int64
#  10  Num_of_Delayed_Payment    70805 non-null  int64
#  11  Changed_Credit_Limit      70805 non-null  float64
#  12  Num_Credit_Inquiries      70805 non-null  float64
# ...

# %%
df4_dummy=pd.get_dummies(df4,columns=['Month','Occupation','Credit_Mix','Payment_of_Min_Amount','Payment_Behaviour','Credit_Score'],drop_first=True)

# %%
df4_dummy
# Out:
#              Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 1      23.000000       19114.12            4194.170850                3.0
# 2      32.931101       19114.12            4194.170850                3.0
# 3      23.000000       19114.12            4194.170850                3.0
# 4      23.000000       19114.12            1824.843333                3.0
# 5      23.000000       19114.12            4194.170850                3.0
# ...          ...            ...                    ...                ...
# 99991  29.000000       20002.88            1929.906667               10.0
# 99993  25.000000       39628.99            3359.415833                4.0
# 99997  25.000000       39628.99            3359.415833                4.0
# 99998  25.000000       39628.99            3359.415833                4.0
# 99999  25.000000       39628.99            3359.415833                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# ...

# %%
df4_dummy.shape
# Out:
# (70805, 49)

# %%
df5=df4_dummy.copy()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70805 entries, 1 to 99999
# Data columns (total 49 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Age                                                 70805 non-null  float64
#  1   Annual_Income                                       70805 non-null  float64
#  2   Monthly_Inhand_Salary                               70805 non-null  float64
#  3   Num_Bank_Accounts                                   70805 non-null  float64
#  4   Num_Credit_Card                                     70805 non-null  int64
#  5   Interest_Rate                                       70805 non-null  int64
#  6   Num_of_Loan                                         70805 non-null  int64
#  7   Delay_from_due_date                                 70805 non-null  int64
# ...

# %%
X=df5.drop(['Credit_Score_Poor','Credit_Score_Standard'],axis=1)
y=df5[['Credit_Score_Poor','Credit_Score_Standard']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
lr_model=LinearRegression()
scaler=StandardScaler()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
lr_model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(X_test_scaled,y_test)
# Out:
# 0.18630157209791665

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()

# %%
log_model.fit(X_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 log_model.fit(X_train_scaled,y_train)
#
# File ~\New folder\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\New folder\Lib\site-packages\sklearn\linear_model\_logistic.py:1207, in LogisticRegression.fit(self, X, y, sample_weight)
#    1204 else:
#    1205     _dtype = [np.float64, np.float32]
# -> 1207 X, y = self._validate_data(
#    1208     X,
#    1209     y,
#    1210     accept_sparse="csr",
#    1211     dtype=_dtype,
# ...
